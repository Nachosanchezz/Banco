# %%
import yfinance as yf
import pandas as pd

# Definir los símbolos de las acciones
bbva_ticker = "BBVA.MC"   # BBVA (Bolsa de Madrid)
santander_ticker = "SAN.MC"  # Banco Santander (Bolsa de Madrid)

# Definir el rango de fechas
start_date = "2000-01-01"
end_date   = "2025-11-01"

# Descargar los datos históricos desde Yahoo Finance
bbva_data = yf.download(bbva_ticker, start=start_date, end=end_date)
santander_data = yf.download(santander_ticker, start=start_date, end=end_date)

# Mostrar resumen por consola
print("BBVA data:")
print(bbva_data.head())
print("\nSantander data:")
print(santander_data.head())

# Guardar los datos en CSV
bbva_data.to_csv("../data/bbva_data.csv")
santander_data.to_csv("../data/santander_data.csv")
# Out:
# C:\Users\1cnac\AppData\Local\Temp\ipykernel_27908\2385928213.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   bbva_data = yf.download(bbva_ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\1cnac\AppData\Local\Temp\ipykernel_27908\2385928213.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   santander_data = yf.download(santander_ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed
# BBVA data:
# Price          Close      High       Low      Open    Volume
# Ticker       BBVA.MC   BBVA.MC   BBVA.MC   BBVA.MC   BBVA.MC
# Date
# 2000-01-03  4.115112  4.155741  4.106406  4.135427   8244257
# 2000-01-04  4.007734  4.088991  3.993224  4.062873   8522096
# 2000-01-05  3.917770  3.990321  3.900358  3.970007  12159826
# 2000-01-06  3.917770  3.917770  3.917770  3.917770         0
# 2000-01-07  3.967106  4.001930  3.926477  4.001930  62261944
#
# Santander data:
# Price          Close      High       Low      Open   Volume
# Ticker        SAN.MC    SAN.MC    SAN.MC    SAN.MC   SAN.MC
# Date
# 2000-01-03  2.625066  2.661974  2.595079  2.652747  8797337
# 2000-01-04  2.562785  2.606613  2.539718  2.592773  8811013
# 2000-01-05  2.500502  2.546636  2.479741  2.514342  9333517
# 2000-01-06  2.500502  2.500502  2.500502  2.500502        0
# 2000-01-07  2.611225  2.618145  2.516649  2.518956  9603132
